# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("rishikeshkonapure/hr-analytics-prediction")

# print("Path to dataset files:", path)

# %%
import pandas as pd #importing pandas library

# %%
df=pd.read_csv("HR-Employee-Attrition.csv") #loading the dataset

# %%
df.head()   #head is used to view top 5 rows of the table
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info() #info is used to get brief information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
# Deleting unnecessary columns
# Renaming the columns
# Dropping duplicates
# Removeing Null Values from the dataset
# Checking for some morer Transformations
# '''

# %%
df.columns  #it is used to see all the columns in the dataset
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
columns_keep=['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education','Gender','HourlyRate','JobRole','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']
columns_drop=['EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction','JobInvolvement', 'JobLevel','JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',]

# %%
len(columns_keep)
# Out:
# 14

# %%
len(columns_drop)
# Out:
# 21

# %%
df=df[columns_keep]

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  Gender  HourlyRate  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'Gender', 'HourlyRate', 'JobRole',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
n_columns=[]
for i in df.columns:
    n_columns.append(i.capitalize()) #this for loop is written to capitalize the columns in data

# %%
df.columns=n_columns

# %%
df.rename(columns={"Distancefromhome":"DistanceHome"},inplace=True)

# %%
df.rename(columns={"Dailyrate":"Dailywage","Hourlyrate":"Hourlywage"},inplace=True)

# %%
df
# Out:
#       Age Attrition     Businesstravel  Dailywage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  Gender  Hourlywage                    Jobrole  \
# ...

# %%
df.duplicated().sum()  #checking the duplicates
# Out:
# 0

# %%
df[df["Yearsatcompany"]<=8].shape #checking the shape of Yearsatcompany less than 8
# Out:
# (1022, 14)

# %%
df[df["Attrition"]=="Yes"]["Attrition"].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
df["Businesstravel"]=df["Businesstravel"].str.replace("_","") #replacing _ with ""

# %%
df
# Out:
#       Age Attrition    Businesstravel  Dailywage              Department  \
# 0      41       Yes      TravelRarely       1102                   Sales
# 1      49        No  TravelFrequently        279  Research & Development
# 2      37       Yes      TravelRarely       1373  Research & Development
# 3      33        No  TravelFrequently       1392  Research & Development
# 4      27        No      TravelRarely        591  Research & Development
# ...   ...       ...               ...        ...                     ...
# 1465   36        No  TravelFrequently        884  Research & Development
# 1466   39        No      TravelRarely        613  Research & Development
# 1467   27        No      TravelRarely        155  Research & Development
# 1468   49        No  TravelFrequently       1023                   Sales
# 1469   34        No      TravelRarely        628  Research & Development
#
#       DistanceHome  Education  Gender  Hourlywage                    Jobrole  \
# ...

# %%
df.isna().sum() #checking the null values
# Out:
# Age                        0
# Attrition                  0
# Businesstravel             0
# Dailywage                  0
# Department                 0
# DistanceHome               0
# Education                  0
# Gender                     0
# Hourlywage                 0
# Jobrole                    0
# Yearsatcompany             0
# Yearsincurrentrole         0
# Yearssincelastpromotion    0
# Yearswithcurrmanager       0
# dtype: int64

# %%
df["Attrition"]=df["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)   #used to change yes no to 0 1

# %%
df
# Out:
#       Age  Attrition    Businesstravel  Dailywage              Department  \
# 0      41          1      TravelRarely       1102                   Sales
# 1      49          0  TravelFrequently        279  Research & Development
# 2      37          1      TravelRarely       1373  Research & Development
# 3      33          0  TravelFrequently       1392  Research & Development
# 4      27          0      TravelRarely        591  Research & Development
# ...   ...        ...               ...        ...                     ...
# 1465   36          0  TravelFrequently        884  Research & Development
# 1466   39          0      TravelRarely        613  Research & Development
# 1467   27          0      TravelRarely        155  Research & Development
# 1468   49          0  TravelFrequently       1023                   Sales
# 1469   34          0      TravelRarely        628  Research & Development
#
#       DistanceHome  Education  Gender  Hourlywage                    Jobrole  \
# ...

# %%
df.reset_index(inplace=True) # resting index

# %%
df
# Out:
#       index  Age  Attrition    Businesstravel  Dailywage  \
# 0         0   41          1      TravelRarely       1102
# 1         1   49          0  TravelFrequently        279
# 2         2   37          1      TravelRarely       1373
# 3         3   33          0  TravelFrequently       1392
# 4         4   27          0      TravelRarely        591
# ...     ...  ...        ...               ...        ...
# 1465   1465   36          0  TravelFrequently        884
# 1466   1466   39          0      TravelRarely        613
# 1467   1467   27          0      TravelRarely        155
# 1468   1468   49          0  TravelFrequently       1023
# 1469   1469   34          0      TravelRarely        628
#
#                   Department  DistanceHome  Education  Gender  Hourlywage  \
# 0                      Sales             1          2  Female          94
# 1     Research & Development             8          1    Male          61
# ...

# %%
# if we want to export cleaned data file
#df.to_excel("Data_Cleaning_Zomato.xlsx")  || for xslx file
#df.to_csv("Data_Cleaning_Zomato.csv")    || for csv file
