# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("mukuldeshantri/ecommerce-fashion-dataset")

# print("Path to dataset files:", path)

# %%
import pandas as pd
df=pd.read_csv("FashionDataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    BrandName                                            Deatils  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='object')

# %%
df.shape
# Out:
# (30758, 8)

# %%
 # Deleting unnecessary columns
# Renaming the columns
# Dropping duplicates
# Removeing Null Values from the dataset
# Checking for some morer Transformations
# '''

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#          BrandName                                            Deatils  \
# 0             life  solid cotton blend collar neck womens a-line d...
# 1             only  polyester peter pan collar womens blouson dres...
# 2          fratini  solid polyester blend wide neck womens regular...
# 3      zink london  stripes polyester sweetheart neck womens dress...
# 4             life  regular fit regular length denim womens jeans ...
# ...            ...                                                ...
# 30753    swarovski            crystal stylish womens rodhium earrings
# 30754          Nan                                                Nan
# 30755       jewelz                 ethnic gold plated jhumki earrings
# 30756      estelle  womens gold plated double line fancy white and...
# 30757      estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  30758 non-null  object
#  1   Deatils    30758 non-null  object
#  2   Sizes      30758 non-null  object
#  3   MRP        30758 non-null  object
#  4   SellPrice  30758 non-null  object
#  5   Discount   30758 non-null  object
#  6   Category   30758 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
df.isna().sum()
# Out:
# BrandName    0
# Deatils      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice', 'Discount',
#        'Category'],
#       dtype='object')

# %%
 df.rename(columns={'Deatils':"Details"},inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
df.duplicated().value_counts().plot(kind="pie")
plt.title("Duplicated Values")
plt.xlabel("")
plt.legend()
plt.show()

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.reset_index().drop(columns="index")
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df["BrandName"]=df["BrandName"].apply (lambda x: x.capitalize())

# %%
df["BrandName"]
# Out:
# 0                      Life
# 1                      Only
# 2                   Fratini
# 3               Zink london
# 4                      Life
#                 ...
# 30752    Shaya by caratlane
# 30753             Swarovski
# 30755                Jewelz
# 30756               Estelle
# 30757               Estelle
# Name: BrandName, Length: 27931, dtype: object

# %%
 df["Sizes"]= df["Sizes"].replace ("NaN","NA VALUED")

# %%
 df["Discount"]= df["Discount"].replace ("Nan","No Discount")

# %%
df[df["Sizes"] != "na valued"]
# Out:
#                 BrandName                                            Details  \
# 0                    Life  solid cotton blend collar neck womens a-line d...
# 1                    Only  polyester peter pan collar womens blouson dres...
# 2                 Fratini  solid polyester blend wide neck womens regular...
# 3             Zink london  stripes polyester sweetheart neck womens dress...
# 4                    Life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 30752  Shaya by caratlane               the wing woman clover charm necklace
# 30753           Swarovski            crystal stylish womens rodhium earrings
# 30755              Jewelz                 ethnic gold plated jhumki earrings
# 30756             Estelle  womens gold plated double line fancy white and...
# 30757             Estelle  womens gold plated bridge designer mangalsutra...
#
# ...

# %%
df.reset_index()
# Out:
#        index           BrandName  \
# 0          0                Life
# 1          1                Only
# 2          2             Fratini
# 3          3         Zink london
# 4          4                Life
# ...      ...                 ...
# 27926  30752  Shaya by caratlane
# 27927  30753           Swarovski
# 27928  30755              Jewelz
# 27929  30756             Estelle
# 27930  30757             Estelle
#
#                                                  Details  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 27926               the wing woman clover charm necklace
# 27927            crystal stylish womens rodhium earrings
# ...

# %%
df.head()
# Out:
#      BrandName                                            Details  \
# 0         Life  solid cotton blend collar neck womens a-line d...
# 1         Only  polyester peter pan collar womens blouson dres...
# 2      Fratini  solid polyester blend wide neck womens regular...
# 3  Zink london  stripes polyester sweetheart neck womens dress...
# 4         Life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
# if we want to export cleaned data file
#df.to_excel("Data_Cleaning_FashionDataset.xlsx")  || for xslx file
#df.to_csv("Data_Cleaning_FashionDataset.csv")    || for csv file
